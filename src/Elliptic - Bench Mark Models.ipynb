# %%
# importing dependencies 
import cryptoaml.datareader as cdr

# %%
# create a new instance for Elliptic Dataset
ell = cdr.get_data("elliptic", 
                   encode_classes=True,
                   cat_class_feats=True)

# %%
display(ell.node_labels.head())
print(ell.node_labels.dtypes)
ell.node_labels["class"].value_counts()
# Out:
#         txId  class
# 0  230425980     -1
# 1    5530458     -1
# 2  232022460     -1
# 3  232438397      0
# 4  230460314     -1
# txId     int64
# class    int64
# dtype: object
# -1    157205
#  0     42019
#  1      4545
# Name: class, dtype: int64

# %%
display(ell.node_edges.tail())

print(ell.node_edges.shape)
print(ell.node_edges.dtypes)
# Out:
#             txId1      txId2
# 234350  158365409  157930723
# 234351  188708874  188708879
# 234352  157659064  157659046
# 234353   87414554  106877725
# 234354  158589452  158589457
# (234355, 2)
# txId1    int64
# txId2    int64
# dtype: object

# %%
display(ell.node_feats.shape)
display(ell.node_feats.head())
print(ell.node_feats.dtypes)
# Out:
# (203769, 168)
#         txId  ts      LF_0      LF_1      LF_2       LF_3      LF_4      LF_5  \
# 0  230425980   1 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875 -0.113002
# 1    5530458   1 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875 -0.113002
# 2  232022460   1 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875 -0.113002
# 3  232438397   1  0.163054  1.963790 -0.646376  12.409294 -0.063725  9.782742
# 4  230460314   1  1.011523 -0.081127 -1.201369   1.153668  0.333276  1.312656
#
#         LF_6      LF_7  ...    agg_feat_63  agg_feat_64  agg_feat_65  \
# 0  -0.061584 -0.162097  ...      -0.600999     1.461330     1.461369
# 1  -0.061584 -0.162112  ...       0.673103    -0.979074    -0.978556
# 2  -0.061584 -0.162749  ...       0.439728    -0.979074    -0.978556
# 3  12.414558 -0.163645  ...      -0.613614     0.241128     0.241406
# 4  -0.061584 -0.163523  ...      -0.400422     0.517257     0.579382
#
# ...
