# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
top_N = 10
experiment_1 = "persistence/experiment_1/tuning_studies/"

# %% [markdown]
# ## XGBoost

# %%
print("XGBoost - Hyperparameter tuning study LF")
study_xgboost_LF = util.read_pickle(experiment_1 + "study_xgboost_LF.pkl").trials_dataframe()
display(study_xgboost_LF.sort_values("value", ascending=False).head(top_N))

print("XGBoost - Hyperparameter tuning study LF_NE")
study_xgboost_LF_NE = util.read_pickle(experiment_1 + "study_xgboost_LF_NE.pkl").trials_dataframe()
display(study_xgboost_LF_NE.sort_values("value", ascending=False).head(top_N))

print("XGBoost - Hyperparameter tuning study AF")
study_xgboost_AF = util.read_pickle(experiment_1 + "study_xgboost_AF.pkl").trials_dataframe()
display(study_xgboost_AF.sort_values("value", ascending=False).head(top_N))

print("XGBoost - Hyperparameter tuning study AF_NE")
study_xgboost_AF_NE = util.read_pickle(experiment_1 + "study_xgboost_AF_NE.pkl").trials_dataframe()
display(study_xgboost_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# XGBoost - Hyperparameter tuning study LF
#     number     value             datetime_start          datetime_complete  \
# 25      25  0.971123 2020-05-02 04:39:55.031657 2020-05-02 04:50:26.452012
# 36      36  0.971119 2020-05-02 06:29:16.116778 2020-05-02 06:40:19.188782
# 26      26  0.971113 2020-05-02 04:50:26.456966 2020-05-02 05:00:43.130062
# 17      17  0.971058 2020-05-02 03:08:15.341204 2020-05-02 03:20:43.108483
# 27      27  0.971017 2020-05-02 05:00:43.134938 2020-05-02 05:11:02.006840
# 45      45  0.970962 2020-05-02 08:03:24.884460 2020-05-02 08:15:01.943927
# 34      34  0.970958 2020-05-02 06:09:47.358367 2020-05-02 06:20:41.934192
# 40      40  0.970857 2020-05-02 07:11:14.836603 2020-05-02 07:22:14.903218
# 29      29  0.970840 2020-05-02 05:20:20.631526 2020-05-02 05:29:51.888548
# 42      42  0.970804 2020-05-02 07:32:17.975875 2020-05-02 07:42:58.096262
#
#     params_colsample_bylevel  params_colsample_bytree  params_gamma  \
# ...

# %% [markdown]
# ## LightGBM

# %%
print("LightGBM - Hyperparameter tuning study LF")
study_lightgbm_LF = util.read_pickle(experiment_1 + "study_lightgbm_LF.pkl").trials_dataframe()
display(study_lightgbm_LF.sort_values("value", ascending=False).head(top_N))

print("LightGBM - Hyperparameter tuning study LF_NE")
study_lightgbm_LF_NE = util.read_pickle(experiment_1 + "study_lightgbm_LF_NE.pkl").trials_dataframe()
display(study_lightgbm_LF_NE.sort_values("value", ascending=False).head(top_N))

print("LightGBM - Hyperparameter tuning study AF")
study_lightgbm_AF = util.read_pickle(experiment_1 + "study_lightgbm_AF.pkl").trials_dataframe()
display(study_lightgbm_AF.sort_values("value", ascending=False).head(top_N))

print("LightGBM - Hyperparameter tuning study AF_NE")
study_lightgbm_AF_NE = util.read_pickle(experiment_1 + "study_lightgbm_AF_NE.pkl").trials_dataframe()
display(study_lightgbm_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# LightGBM - Hyperparameter tuning study LF
#     number     value             datetime_start          datetime_complete  \
# 33      33  0.970560 2020-05-02 10:30:58.735469 2020-05-02 10:34:37.290034
# 34      34  0.970159 2020-05-02 10:34:37.295456 2020-05-02 10:37:22.587611
# 31      31  0.970105 2020-05-02 10:22:14.485546 2020-05-02 10:26:43.610142
# 39      39  0.970104 2020-05-02 10:46:21.642379 2020-05-02 10:48:25.659305
# 35      35  0.969953 2020-05-02 10:37:22.593632 2020-05-02 10:40:11.081464
# 17      17  0.969847 2020-05-02 09:35:05.403143 2020-05-02 09:38:58.891755
# 18      18  0.969694 2020-05-02 09:38:58.895198 2020-05-02 09:42:36.369128
# 21      21  0.969673 2020-05-02 09:46:04.544715 2020-05-02 09:50:10.556143
# 16      16  0.969374 2020-05-02 09:30:50.756461 2020-05-02 09:35:05.399844
# 42      42  0.969178 2020-05-02 10:52:27.936298 2020-05-02 10:56:08.376901
#
#     params_colsample_bytree  params_learning_rate  params_min_child_samples  \
# ...

# %% [markdown]
# ## CatBoost

# %%
print("CatBoost - Hyperparameter tuning study LF")
study_catboost_LF = util.read_pickle(experiment_1 + "study_catboost_LF.pkl").trials_dataframe()
display(study_catboost_LF.sort_values("value", ascending=False).head(top_N))

print("CatBoost - Hyperparameter tuning study LF_NE")
study_catboost_LF_NE = util.read_pickle(experiment_1 + "study_catboost_LF_NE.pkl").trials_dataframe()
display(study_catboost_LF_NE.sort_values("value", ascending=False).head(top_N))

print("CatBoost - Hyperparameter tuning study AF")
study_catboost_AF = util.read_pickle(experiment_1 + "study_catboost_AF.pkl").trials_dataframe()
display(study_catboost_AF.sort_values("value", ascending=False).head(top_N))

print("CatBoost - Hyperparameter tuning study AF_NE")
study_catboost_AF_NE = util.read_pickle(experiment_1 + "study_catboost_AF_NE.pkl").trials_dataframe()
display(study_catboost_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# CatBoost - Hyperparameter tuning study LF
#     number     value             datetime_start          datetime_complete  \
# 46      46  0.968898 2020-05-02 15:50:42.836454 2020-05-02 15:55:59.513740
# 11      11  0.968643 2020-05-02 12:13:57.567464 2020-05-02 12:20:48.974141
# 7        7  0.968585 2020-05-02 12:01:44.093828 2020-05-02 12:04:53.116714
# 3        3  0.968316 2020-05-02 11:28:53.480310 2020-05-02 11:35:34.075956
# 44      44  0.968224 2020-05-02 15:38:29.287469 2020-05-02 15:44:48.840022
# 42      42  0.968094 2020-05-02 15:27:54.739480 2020-05-02 15:32:21.863783
# 43      43  0.968042 2020-05-02 15:32:21.869985 2020-05-02 15:38:29.281130
# 31      31  0.968034 2020-05-02 14:21:52.331847 2020-05-02 14:26:36.361415
# 23      23  0.967909 2020-05-02 13:34:40.815986 2020-05-02 13:39:19.286110
# 39      39  0.967834 2020-05-02 15:14:46.281343 2020-05-02 15:20:05.593929
#
#     params_depth  params_l2_leaf_reg  params_leaf_estimation_iterations  \
# ...
