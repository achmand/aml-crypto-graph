# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
top_N = 10
experiment_1 = "persistence/experiment_1/tuning_studies/"

# %% [markdown]
# ## XGBoost

# %%
print("XGBoost - Hyperparameter tuning study AF")
study_xgboost = util.read_pickle(experiment_1 + "study_xgboost_AF.pkl").trials_dataframe()
display(study_xgboost.sort_values("value", ascending=False).head(top_N))
# Out:
# XGBoost - Hyperparameter tuning study AF
#     number     value             datetime_start          datetime_complete  \
# 36      36  0.975578 2020-05-02 04:29:20.419076 2020-05-02 04:36:50.443990
# 21      21  0.975003 2020-05-02 02:24:09.057132 2020-05-02 02:33:15.795543
# 23      23  0.974963 2020-05-02 02:42:31.797206 2020-05-02 02:51:24.261361
# 40      40  0.974857 2020-05-02 04:58:01.113369 2020-05-02 05:06:05.969624
# 49      49  0.974854 2020-05-02 06:07:53.367851 2020-05-02 06:16:50.214988
# 34      34  0.974818 2020-05-02 04:14:04.889139 2020-05-02 04:21:34.645422
# 30      30  0.974702 2020-05-02 03:40:57.738271 2020-05-02 03:49:35.835364
# 13      13  0.974674 2020-05-02 01:03:16.730347 2020-05-02 01:12:53.939061
# 44      44  0.974577 2020-05-02 05:30:04.868640 2020-05-02 05:37:44.077373
# 33      33  0.974539 2020-05-02 04:05:25.713201 2020-05-02 04:14:04.884055
#
#     params_colsample_bylevel  params_colsample_bytree  params_gamma  \
# ...

# %% [markdown]
# ## LightGBM

# %%
print("LightGBM - Hyperparameter tuning study AF")
study_lightgbm = util.read_pickle(experiment_1 + "study_lightgbm_AF.pkl").trials_dataframe()
display(study_lightgbm.sort_values("value", ascending=False).head(top_N))
# Out:
# LightGBM - Hyperparameter tuning study AF
#     number     value             datetime_start          datetime_complete  \
# 42      42  0.976045 2020-05-02 07:52:11.858756 2020-05-02 07:54:04.342491
# 44      44  0.975906 2020-05-02 07:56:12.321583 2020-05-02 07:58:23.827517
# 43      43  0.975899 2020-05-02 07:54:04.348908 2020-05-02 07:56:12.315617
# 23      23  0.975895 2020-05-02 07:02:00.721351 2020-05-02 07:04:29.702620
# 31      31  0.975777 2020-05-02 07:25:21.295829 2020-05-02 07:27:35.332625
# 40      40  0.975740 2020-05-02 07:46:34.669774 2020-05-02 07:49:22.656888
# 45      45  0.975739 2020-05-02 07:58:23.833562 2020-05-02 08:00:14.325291
# 26      26  0.975609 2020-05-02 07:09:11.706346 2020-05-02 07:12:35.588183
# 47      47  0.975464 2020-05-02 08:02:15.729557 2020-05-02 08:03:55.246397
# 33      33  0.975308 2020-05-02 07:29:43.767150 2020-05-02 07:32:00.016776
#
#     params_colsample_bytree  params_learning_rate  params_min_child_samples  \
# ...

# %% [markdown]
# ## CatBoost
