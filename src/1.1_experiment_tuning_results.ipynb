# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
experiment_1 = "persistence/experiment_1.1/tuning_studies/"

# %%
# XGBOOST
print("XGBOOST ALL RS")
study_rsxgb_ALL = util.read_pickle(experiment_1 + "rs_xgboost_ALL.pkl")
study_rsxgb_LF_df = study_rsxgb_ALL.trials_dataframe()
display(study_rsxgb_LF_df[study_rsxgb_LF_df["state"] == "COMPLETE"].sort_values("value", ascending=False))

# print("XGBOOST LF TPE")
# study_tpexgb_LF = util.read_pickle(experiment_1 + "tpe_xgboost_LF.pkl")
# study_tpexgb_LF_df = study_tpexgb_LF.trials_dataframe()
# display(study_tpexgb_LF_df[study_tpexgb_LF_df["state"] == "COMPLETE"].sort_values("value", ascending=False))
# Out:
# XGBOOST ALL RS
#     number     value             datetime_start          datetime_complete  \
# 27      27  0.986526 2020-04-29 00:42:29.069676 2020-04-29 00:42:36.619626
# 75      75  0.986253 2020-04-29 00:50:18.284724 2020-04-29 00:50:21.824243
# 62      62  0.985916 2020-04-29 00:48:01.580537 2020-04-29 00:48:13.294255
# 94      94  0.985905 2020-04-29 00:53:19.657000 2020-04-29 00:53:23.592007
# 12      12  0.985905 2020-04-29 00:39:54.807125 2020-04-29 00:40:00.302802
# ..     ...       ...                        ...                        ...
# 50      50  0.982645 2020-04-29 00:46:05.225169 2020-04-29 00:46:09.706494
# 59      59  0.982637 2020-04-29 00:47:34.802078 2020-04-29 00:47:41.461428
# 79      79  0.982616 2020-04-29 00:50:51.508070 2020-04-29 00:50:55.797083
# 65      65  0.982326 2020-04-29 00:48:30.948412 2020-04-29 00:48:52.699030
# 32      32  0.981969 2020-04-29 00:43:13.312736 2020-04-29 00:43:20.756073
#
# ...

# %%
# LIGHTGBM 
print("LIGHTGBM ALL RS")
study_rslight_ALL = util.read_pickle(experiment_1 + "rs_lightgbm_ALL.pkl")
study_rslight_ALL_df = study_rslight_ALL.trials_dataframe()
display(study_rslight_ALL_df[study_rslight_ALL_df["state"] == "COMPLETE"].sort_values("value", ascending=False))

print("LIGHTGBM ALL TPE")
study_tpelight_ALL = util.read_pickle(experiment_1 + "tpe_lightgbm_ALL.pkl")
study_tpelight_ALL_df = study_tpelight_ALL.trials_dataframe()
display(study_tpelight_ALL_df[study_tpelight_ALL_df["state"] == "COMPLETE"].sort_values("value", ascending=False))
