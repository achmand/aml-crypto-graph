# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
experiment_1 = "persistence/experiment_1.1/tuning_studies/"

# %%
# XGBOOST
# print("XGBOOST LF GS")
# study_gsxgb_LF = util.read_pickle(experiment_1 + "rs_xgboost_LF.pkl")
# study_gsxgb_LF_df = study_gsxgb_LF.trials_dataframe()
# display(study_gsxgb_LF_df[study_gsxgb_LF_df["state"] == "COMPLETE"].sort_values("value", ascending=False))

# print("XGBOOST LF TPE")
# study_tpexgb_LF = util.read_pickle(experiment_1 + "tpe_xgboost_LF.pkl")
# study_tpexgb_LF_df = study_tpexgb_LF.trials_dataframe()
# display(study_tpexgb_LF_df[study_tpexgb_LF_df["state"] == "COMPLETE"].sort_values("value", ascending=False))

# %%
# LIGHTGBM 
# print("LIGHTGBM LF GS")
# study_gslight_LF = util.read_pickle(experiment_1 + "rs_lightgbm_LF.pkl")
# study_gslight_LF_df = study_gslight_LF.trials_dataframe()
# display(study_gslight_LF_df[study_gslight_LF_df["state"] == "COMPLETE"].sort_values("value", ascending=False))

# print("LIGHTGBM LF TPE")
# study_tpelight_LF = util.read_pickle(experiment_1 + "tpe_lightgbm_LF.pkl")
# study_tpelight_LF_df = study_tpelight_LF.trials_dataframe()
# display(study_tpelight_LF_df[study_tpelight_LF_df["state"] == "COMPLETE"].sort_values("value", ascending=False))

# %%
# CATBOOST
print("CATBOOST ALL RS")
study_gscat_ALL = util.read_pickle(experiment_1 + "rs_catboost_ALL.pkl")
study_gscat_ALL_df = study_gscat_ALL.trials_dataframe()
display(study_gscat_ALL_df[study_gscat_ALL_df["state"] == "COMPLETE"].sort_values("value", ascending=False))
# Out:
# CATBOOST ALL RS
#     number     value             datetime_start          datetime_complete  \
# 46      46  0.987851 2020-04-28 23:53:41.839573 2020-04-28 23:54:28.568270
# 98      98  0.987849 2020-04-29 00:15:35.177147 2020-04-29 00:16:39.129041
# 74      74  0.987208 2020-04-29 00:05:04.862618 2020-04-29 00:05:32.031327
# 80      80  0.987185 2020-04-29 00:07:29.245855 2020-04-29 00:08:24.232390
# 71      71  0.987184 2020-04-29 00:03:31.323203 2020-04-29 00:04:19.708719
# ..     ...       ...                        ...                        ...
# 15      15  0.982234 2020-04-28 23:40:51.481442 2020-04-28 23:41:02.914453
# 31      31  0.981985 2020-04-28 23:46:27.433851 2020-04-28 23:46:38.469925
# 5        5  0.981920 2020-04-28 23:35:54.183526 2020-04-28 23:36:16.967480
# 60      60  0.981602 2020-04-28 23:59:54.218561 2020-04-29 00:00:07.017142
# 51      51  0.981342 2020-04-28 23:55:51.663945 2020-04-28 23:56:07.505424
#
# ...
