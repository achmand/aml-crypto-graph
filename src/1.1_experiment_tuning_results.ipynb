# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
top_N = 10
experiment_1 = "persistence/experiment_1.1/tuning_studies/"

# %% [markdown]
# ## LightGBM

# %%
print("CatBoost - Hyperparameter tuning study")
study_lightgbm = util.read_pickle(experiment_1 + "study_lightgbm_ALL.pkl").trials_dataframe()
display(study_lightgbm.sort_values("value", ascending=False).head(top_N))
# Out:
# CatBoost - Hyperparameter tuning study
#     number     value             datetime_start          datetime_complete  \
# 12      12  0.985176 2020-04-30 23:11:51.043018 2020-04-30 23:12:23.910454
# 32      32  0.984863 2020-04-30 23:26:09.063603 2020-04-30 23:26:48.050837
# 42      42  0.984553 2020-04-30 23:32:24.404578 2020-04-30 23:33:03.287601
# 46      46  0.984542 2020-04-30 23:35:07.167893 2020-04-30 23:35:42.272161
# 49      49  0.984519 2020-04-30 23:36:57.764388 2020-04-30 23:37:37.232989
# 25      25  0.984507 2020-04-30 23:20:03.703615 2020-04-30 23:21:02.801010
# 33      33  0.984193 2020-04-30 23:26:48.055954 2020-04-30 23:27:26.197680
# 29      29  0.983883 2020-04-30 23:22:46.120242 2020-04-30 23:23:48.371179
# 48      48  0.983848 2020-04-30 23:36:16.480883 2020-04-30 23:36:57.756932
# 15      15  0.983843 2020-04-30 23:13:26.061796 2020-04-30 23:14:17.868178
#
#     params_colsample_bytree  params_learning_rate  params_min_child_samples  \
# ...

# %% [markdown]
# ### CatBoost

# %%
print("CatBoost - Hyperparameter tuning study")
study_catboost = util.read_pickle(experiment_1 + "study_catboost_ALL.pkl").trials_dataframe()
display(study_catboost.sort_values("value", ascending=False).head(top_N))
# Out:
# CatBoost - Hyperparameter tuning study
#     number     value             datetime_start          datetime_complete  \
# 40      40  0.985177 2020-05-01 00:57:53.735027 2020-05-01 00:59:13.855330
# 49      49  0.984826 2020-05-01 01:09:56.951298 2020-05-01 01:10:50.853850
# 5        5  0.984515 2020-04-30 23:56:15.584869 2020-04-30 23:57:20.733478
# 45      45  0.984177 2020-05-01 01:05:41.235259 2020-05-01 01:07:02.815410
# 48      48  0.984175 2020-05-01 01:09:02.500440 2020-05-01 01:09:56.944638
# 46      46  0.984170 2020-05-01 01:07:02.821463 2020-05-01 01:07:59.135863
# 34      34  0.983875 2020-05-01 00:42:42.216312 2020-05-01 00:45:10.889414
# 27      27  0.983857 2020-05-01 00:25:41.661283 2020-05-01 00:27:59.573646
# 22      22  0.983856 2020-05-01 00:14:47.964261 2020-05-01 00:17:11.245287
# 6        6  0.983850 2020-04-30 23:57:20.734953 2020-04-30 23:58:12.285356
#
#     params_depth  params_l2_leaf_reg  params_leaf_estimation_iterations  \
# ...
