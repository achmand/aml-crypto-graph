# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
top_N = 10
experiment_1 = "persistence/experiment_1.1/tuning_studies/"

# %%
# LightGBM 
print("LightGBM - Random Search: 'Learning Rate' & 'No. of estimators'")
lighgbm_rs = util.read_pickle(experiment_1 + "rs_lightgbm_ALL.pkl").trials_dataframe()
display(lighgbm_rs.sort_values("value", ascending=False).head(top_N))

print("LightGBM - TPE")
lighgbm_tpe = util.read_pickle(experiment_1 + "tpe_lightgbm_ALL.pkl").trials_dataframe()
display(lighgbm_tpe.sort_values("value", ascending=False).head(top_N))
# Out:
# LightGBM - Random Search: 'Learning Rate' & 'No. of estimators'
#     number     value             datetime_start          datetime_complete  \
# 6        6  0.986854 2020-04-29 21:25:28.725901 2020-04-29 21:26:26.074923
# 15      15  0.985863 2020-04-29 21:34:54.571043 2020-04-29 21:35:46.747327
# 30      30  0.985858 2020-04-29 21:51:09.560517 2020-04-29 21:51:59.647694
# 4        4  0.985566 2020-04-29 21:23:27.658560 2020-04-29 21:24:28.560264
# 7        7  0.985537 2020-04-29 21:26:26.076867 2020-04-29 21:27:58.450379
# 38      38  0.985238 2020-04-29 21:58:40.317254 2020-04-29 21:59:30.573901
# 29      29  0.985222 2020-04-29 21:49:55.597754 2020-04-29 21:51:09.557571
# 39      39  0.985217 2020-04-29 21:59:30.579253 2020-04-29 22:00:24.452943
# 36      36  0.985206 2020-04-29 21:56:26.591563 2020-04-29 21:57:46.266771
# 3        3  0.984882 2020-04-29 21:22:31.581064 2020-04-29 21:23:27.657179
#
#     params_learning_rate  user_attrs_best_n_estimators  user_attrs_cv_max  \
# ...

# %%
# CatBoost 
print("CatBoost - Random Search: 'Learning Rate' & 'No. of estimators'")
catboost_rs = util.read_pickle(experiment_1 + "rs_catboost_ALL.pkl").trials_dataframe()
display(catboost_rs.sort_values("value", ascending=False).head(top_N))

display(catboost_rs.sort_values("value", ascending=False).head(1).values)
# Out:
# CatBoost - Random Search: 'Learning Rate' & 'No. of estimators'
#     number     value             datetime_start          datetime_complete  \
# 4        4  0.985513 2020-04-30 18:53:39.160136 2020-04-30 18:54:36.584178
# 25      25  0.985211 2020-04-30 19:14:18.765044 2020-04-30 19:15:16.197883
# 26      26  0.985203 2020-04-30 19:15:16.199767 2020-04-30 19:16:13.495308
# 42      42  0.985197 2020-04-30 19:31:10.254855 2020-04-30 19:32:07.598912
# 8        8  0.984843 2020-04-30 18:57:29.111456 2020-04-30 18:58:25.985204
# 38      38  0.984829 2020-04-30 19:27:07.889017 2020-04-30 19:28:05.915908
# 21      21  0.984513 2020-04-30 19:10:22.693165 2020-04-30 19:11:24.698678
# 17      17  0.984511 2020-04-30 19:06:21.278875 2020-04-30 19:07:23.812859
# 46      46  0.984214 2020-04-30 19:35:15.220571 2020-04-30 19:36:13.189797
# 13      13  0.984203 2020-04-30 19:02:24.842377 2020-04-30 19:03:22.351598
#
#     params_learning_rate  user_attrs_best_n_estimators  user_attrs_cv_max  \
# ...
