# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('residual_values.csv') 
# display(df)

# %%
plt.figure(figsize=(15,8))
sns.distplot(df["Residual"], hist=True, color="black", hist_kws={"histtype": "step", "linewidth": 1,
                            "alpha": 0.2, "color": "black"}, rug=False);
