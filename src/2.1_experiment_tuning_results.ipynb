# %%
###### importing dependencies ############################################
from cryptoaml import utils as util  

###### constants #########################################################
top_N = 10
experiment = "persistence/experiment_2.1/tuning_studies/"

# %% [markdown]
# ## Random Forest

# %%
print("Random Forest - Hyperparameter tuning study AF")
study_random_forest_AF = util.read_pickle(experiment + "study_randomforest_AF.pkl").trials_dataframe()
display(study_random_forest_AF.sort_values("value", ascending=False).head(top_N))

print("Random Forest - Hyperparameter tuning study AF_NE")
study_random_forest_AF_NE = util.read_pickle(experiment + "study_randomforest_AF_NE.pkl").trials_dataframe()
display(study_random_forest_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# Random Forest - Hyperparameter tuning study AF
#     number     value             datetime_start          datetime_complete  \
# 31      31  0.961742 2020-05-09 19:51:15.875808 2020-05-09 19:51:43.969624
# 17      17  0.961296 2020-05-09 19:48:58.258657 2020-05-09 19:49:05.982534
# 29      29  0.960966 2020-05-09 19:50:37.007348 2020-05-09 19:50:56.683226
# 35      35  0.960962 2020-05-09 19:52:54.198653 2020-05-09 19:53:20.359811
# 24      24  0.960490 2020-05-09 19:49:45.554023 2020-05-09 19:49:54.845284
# 46      46  0.960251 2020-05-09 19:56:26.646008 2020-05-09 19:56:47.501438
# 28      28  0.960239 2020-05-09 19:50:21.623428 2020-05-09 19:50:37.004215
# 47      47  0.960226 2020-05-09 19:56:47.505874 2020-05-09 19:57:00.057518
# 49      49  0.959939 2020-05-09 19:57:14.121426 2020-05-09 19:57:27.600844
# 20      20  0.959781 2020-05-09 19:49:26.047656 2020-05-09 19:49:31.116598
#
#    params_max_features  params_max_samples  params_n_estimators  \
# ...

# %% [markdown]
# ## XGBoost

# %%
print("XGBoost - Hyperparameter tuning study AF")
study_xgboost_AF = util.read_pickle(experiment + "study_xgboost_AF.pkl").trials_dataframe()
display(study_xgboost_AF.sort_values("value", ascending=False).head(top_N))

print("XGBoost - Hyperparameter tuning study AF_NE")
study_xgboost_AF_NE = util.read_pickle(experiment + "study_xgboost_AF_NE.pkl").trials_dataframe()
display(study_xgboost_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# XGBoost - Hyperparameter tuning study AF
#     number     value             datetime_start          datetime_complete  \
# 36      36  0.977570 2020-05-09 23:49:19.516646 2020-05-09 23:58:22.884095
# 22      22  0.977122 2020-05-09 21:06:33.487546 2020-05-09 21:18:28.099652
# 21      21  0.976796 2020-05-09 20:54:57.037026 2020-05-09 21:06:33.482877
# 40      40  0.976661 2020-05-10 00:26:16.403652 2020-05-10 00:37:43.639221
# 46      46  0.976592 2020-05-10 01:28:27.750079 2020-05-10 01:39:30.867102
# 33      33  0.976522 2020-05-09 23:16:20.145396 2020-05-09 23:27:43.947895
# 29      29  0.976502 2020-05-09 22:32:27.986566 2020-05-09 22:43:25.296486
# 19      19  0.976359 2020-05-09 20:33:52.969585 2020-05-09 20:46:10.081561
# 32      32  0.976194 2020-05-09 23:03:56.914524 2020-05-09 23:16:20.139733
# 28      28  0.976179 2020-05-09 22:18:19.180929 2020-05-09 22:32:27.981353
#
#     params_colsample_bylevel  params_colsample_bytree  params_gamma  \
# ...

# %% [markdown]
# ## LightGBM

# %%
print("LightGBM - Hyperparameter tuning study AF")
study_lightgbm_AF = util.read_pickle(experiment + "study_lightgbm_AF.pkl").trials_dataframe()
display(study_lightgbm_AF.sort_values("value", ascending=False).head(top_N))

print("LightGBM - Hyperparameter tuning study AF_NE")
study_lightgbm_AF_NE = util.read_pickle(experiment + "study_lightgbm_AF_NE.pkl").trials_dataframe()
display(study_lightgbm_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# LightGBM - Hyperparameter tuning study AF
#     number     value             datetime_start          datetime_complete  \
# 49      49  0.978162 2020-05-09 18:40:13.805267 2020-05-09 18:42:18.125434
# 35      35  0.978005 2020-05-09 18:17:27.007973 2020-05-09 18:19:05.799673
# 37      37  0.977881 2020-05-09 18:20:21.925720 2020-05-09 18:21:56.797545
# 31      31  0.977874 2020-05-09 18:07:24.888226 2020-05-09 18:09:42.083605
# 30      30  0.977873 2020-05-09 18:05:11.020686 2020-05-09 18:07:24.883115
# 21      21  0.977744 2020-05-09 17:43:11.349746 2020-05-09 17:44:52.426735
# 17      17  0.977723 2020-05-09 17:31:42.346491 2020-05-09 17:34:24.421397
# 22      22  0.977423 2020-05-09 17:44:52.431688 2020-05-09 17:46:54.775580
# 34      34  0.977291 2020-05-09 18:15:12.794628 2020-05-09 18:17:27.002281
# 14      14  0.977286 2020-05-09 17:25:25.623610 2020-05-09 17:27:13.133960
#
#     params_colsample_bytree  params_learning_rate  params_min_child_samples  \
# ...

# %% [markdown]
# ## CatBoost

# %%
print("CatBoost - Hyperparameter tuning study AF")
study_catboost_AF = util.read_pickle(experiment + "study_catboost_AF.pkl").trials_dataframe()
display(study_catboost_AF.sort_values("value", ascending=False).head(top_N))

print("CatBoost - Hyperparameter tuning study AF_NE")
study_catboost_AF_NE = util.read_pickle(experiment + "study_catboost_AF_NE.pkl").trials_dataframe()
display(study_catboost_AF_NE.sort_values("value", ascending=False).head(top_N))
# Out:
# CatBoost - Hyperparameter tuning study AF
#     number     value             datetime_start          datetime_complete  \
# 40      40  0.977093 2020-05-10 00:42:28.075870 2020-05-10 00:47:34.801072
# 24      24  0.976945 2020-05-09 23:15:24.251758 2020-05-09 23:21:11.733488
# 21      21  0.976369 2020-05-09 23:01:51.692308 2020-05-09 23:06:18.302298
# 5        5  0.976215 2020-05-09 21:33:27.103828 2020-05-09 21:37:44.949902
# 0        0  0.975953 2020-05-09 20:57:47.285130 2020-05-09 21:02:24.225990
# 49      49  0.975931 2020-05-10 01:45:03.924179 2020-05-10 01:49:20.141193
# 29      29  0.975913 2020-05-09 23:45:11.147897 2020-05-09 23:49:38.028222
# 15      15  0.975911 2020-05-09 22:32:37.412305 2020-05-09 22:36:38.761879
# 22      22  0.975896 2020-05-09 23:06:18.305776 2020-05-09 23:10:27.674822
# 25      25  0.975885 2020-05-09 23:21:11.737641 2020-05-09 23:28:19.542975
#
#     params_depth  params_l2_leaf_reg  params_leaf_estimation_iterations  \
# ...
