# %%
import cryptoaml.datareader as cdr

# %%
weather = cdr.get_data("noaa_weather")

# %%
# print(weather["class"].value_counts())

# %%
data = weather.train_test_split(train_size=0.7, as_dict=False)

train_data = data.train_X
test_data = data.test_X

display(train_data)
# Out:
#        temperature  dew_point  sea_level_pressure  visibility  avg_wind_speed  \
# 0             19.8       14.0              1019.6         8.4             9.9
# 1             26.8       22.2              1006.2         8.1            10.9
# 2             34.6       32.9              1004.6         3.9            13.8
# 3             26.4       21.5              1006.9         8.0            18.7
# 4             14.7        7.9              1009.9         8.1            14.1
# ...            ...        ...                 ...         ...             ...
# 12715          3.3       -7.3              1023.5        19.3             2.5
# 12716         16.5       12.2              1015.7        11.7             2.7
# 12717          9.6        2.4              1022.3        12.6            12.4
# 12718          0.5       -9.6              1035.8        20.1             6.9
# 12719          3.0       -6.9              1034.2        19.9             4.1
#
# ...

# %%
display(test_data)
# Out:
#        temperature  dew_point  sea_level_pressure  visibility  avg_wind_speed  \
# 12720         20.9       14.4              1025.3        18.2             5.4
# 12721         25.5       23.2              1029.2         5.2             1.6
# 12722         20.7       18.9              1032.8        10.3             2.4
# 12723         22.3       18.7              1023.9        11.8             2.9
# 12724         31.0       28.0              1018.8        14.7             3.0
# ...            ...        ...                 ...         ...             ...
# 18154         32.6       21.9              1022.7         7.0            12.4
# 18155         36.8       25.4              1014.9         7.0            10.0
# 18156         41.9       29.9              1010.0         7.0             4.7
# 18157         42.4       29.7              1011.3         7.0             3.3
# 18158         36.6       29.5              1017.9         6.8             4.8
#
# ...
